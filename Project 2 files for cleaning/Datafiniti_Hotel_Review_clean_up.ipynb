# %%
# import depend
import pandas as pd
import datetime as dt
import calendar

# %%
# Create a reference to the CSV and import it into a Pandas DataFrame
csv_path = 'Datafiniti_Hotel_Reviews.csv'
df = pd.read_csv(csv_path)
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVwc252WIN2L1WUfpqLP  2016-10-30T21:42:42Z  2018-09-10T21:06:27Z
# 1  AVwc252WIN2L1WUfpqLP  2016-10-30T21:42:42Z  2018-09-10T21:06:27Z
# 2  AVwc252WIN2L1WUfpqLP  2016-10-30T21:42:42Z  2018-09-10T21:06:27Z
# 3  AVwdOclqIN2L1WUfti38  2015-11-28T19:19:35Z  2018-09-10T21:06:16Z
# 4  AVwdOclqIN2L1WUfti38  2015-11-28T19:19:35Z  2018-09-10T21:06:16Z
#
#              address                                         categories  \
# 0  5921 Valencia Cir  Hotels,Hotels and motels,Hotel and motel reser...
# 1  5921 Valencia Cir  Hotels,Hotels and motels,Hotel and motel reser...
# 2  5921 Valencia Cir  Hotels,Hotels and motels,Hotel and motel reser...
# 3     7520 Teague Rd  Hotels,Hotels and motels,Travel agencies and b...
# 4     7520 Teague Rd  Hotels,Hotels and motels,Travel agencies and b...
#
#                primaryCategories             city country  \
# 0  Accommodation & Food Services  Rancho Santa Fe      US
# ...

# %%
# drop all rows not in the city of Las Vegas
index_names = df[df['city']!= 'Las Vegas'].index
df.drop(index_names, inplace=True)
df.head()
# Out:
#                        id             dateAdded           dateUpdated  \
# 154  AWKpI38Q3-Khe5l_hxUR  2018-04-09T05:56:34Z  2018-09-04T21:27:52Z
# 155  AWKlQWNQa4HuVbedPUSi  2018-04-08T12:17:12Z  2018-09-04T21:27:52Z
# 156  AWKlQWNQa4HuVbedPUSi  2018-04-08T12:17:12Z  2018-09-04T21:27:52Z
# 157  AWKlQWNQa4HuVbedPUSi  2018-04-08T12:17:12Z  2018-09-04T21:27:52Z
# 158  AWKlQWNQa4HuVbedPUSi  2018-04-08T12:17:12Z  2018-09-04T21:27:52Z
#
#                    address    categories              primaryCategories  \
# 154  200 North Main Street  Hotels,Hotel  Accommodation & Food Services
# 155     200 Fremont Street  Hotels,Hotel  Accommodation & Food Services
# 156     200 Fremont Street  Hotels,Hotel  Accommodation & Food Services
# 157     200 Fremont Street  Hotels,Hotel  Accommodation & Food Services
# 158     200 Fremont Street  Hotels,Hotel  Accommodation & Food Services
#
#           city country                                          keys  \
# ...

# %%
#get list of column names
column_names = df.columns.values.tolist()
column_names
# Out:
# ['id',
#  'dateAdded',
#  'dateUpdated',
#  'address',
#  'categories',
#  'primaryCategories',
#  'city',
#  'country',
#  'keys',
#  'latitude',
#  'longitude',
#  'name',
#  'postalCode',
#  'province',
#  'reviews.date',
#  'reviews.dateSeen',
#  'reviews.rating',
#  'reviews.sourceURLs',
#  'reviews.text',
#  'reviews.title',
#  'reviews.userCity',
#  'reviews.userProvince',
#  'reviews.username',
#  'sourceURLs',
#  'websites']

# %%
# drop unneeded columns
df = df.drop(['id',
 'dateAdded',
 'dateUpdated',
 'primaryCategories',
 'country',
 'keys',
 'reviews.dateSeen',
 'reviews.sourceURLs',
 'reviews.title',
 'reviews.userCity',
 'reviews.username',
 'sourceURLs',
 'websites'], axis=1)
df.reset_index(inplace=True, drop=True)
df.head()
# Out:
#                  address    categories       city   latitude  longitude  \
# 0  200 North Main Street  Hotels,Hotel  Las Vegas  36.174320 -115.14565
# 1     200 Fremont Street  Hotels,Hotel  Las Vegas  36.170891 -115.14307
# 2     200 Fremont Street  Hotels,Hotel  Las Vegas  36.170891 -115.14307
# 3     200 Fremont Street  Hotels,Hotel  Las Vegas  36.170891 -115.14307
# 4     200 Fremont Street  Hotels,Hotel  Las Vegas  36.170891 -115.14307
#
#                                        name postalCode province  \
# 0  Main Street Station Casino Brewery Hotel      89101       NV
# 1                    Fremont Hotel & Casino      89101       NV
# 2                    Fremont Hotel & Casino      89101       NV
# 3                    Fremont Hotel & Casino      89101       NV
# 4                    Fremont Hotel & Casino      89101       NV
#
#                reviews.date  reviews.rating  \
# 0  2016-11-23T00:00:00.000Z            4.40
# 1  2017-03-15T00:00:00.000Z            2.10
# ...

# %%
# clean date column
df.astype({'reviews.date' :'datetime64[ns]' })
# convert review date column to date time
df['reviews.date'] = pd.to_datetime(df['reviews.date'])
# extract month
df['reviews.date'] = df['reviews.date'].dt.month
# set month int to full name
df['reviews.date'] = df['reviews.date'].apply(lambda x: calendar.month_name[x])
df.head()
# Out:
#                  address    categories       city   latitude  longitude  \
# 0  200 North Main Street  Hotels,Hotel  Las Vegas  36.174320 -115.14565
# 1     200 Fremont Street  Hotels,Hotel  Las Vegas  36.170891 -115.14307
# 2     200 Fremont Street  Hotels,Hotel  Las Vegas  36.170891 -115.14307
# 3     200 Fremont Street  Hotels,Hotel  Las Vegas  36.170891 -115.14307
# 4     200 Fremont Street  Hotels,Hotel  Las Vegas  36.170891 -115.14307
#
#                                        name postalCode province reviews.date  \
# 0  Main Street Station Casino Brewery Hotel      89101       NV     November
# 1                    Fremont Hotel & Casino      89101       NV        March
# 2                    Fremont Hotel & Casino      89101       NV     December
# 3                    Fremont Hotel & Casino      89101       NV      January
# 4                    Fremont Hotel & Casino      89101       NV      January
#
# ...

# %%
df.dtypes
# Out:
# address                  object
# categories               object
# city                     object
# latitude                float64
# longitude               float64
# name                     object
# postalCode               object
# province                 object
# reviews.date             object
# reviews.rating          float64
# reviews.text             object
# reviews.userProvince     object
# dtype: object

# %%
#save cleaned csv for later 
df.to_csv("Datafiniti_Hotel_Review_cleaned.csv", index=False)

# %%
len(df)
# Out:
# 506
