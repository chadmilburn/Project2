# %%
import pandas as pd

# %%
csv_path = '7282_1_cleaned.csv'
reviewsfile1 = pd.read_csv(csv_path)
reviewsfile1.head()
# Out:
#      address categories       city   latitude   longitude  \
# 0  1 Main St     Hotels  Las Vegas  36.171617 -115.146375
# 1  1 Main St     Hotels  Las Vegas  36.171617 -115.146375
# 2  1 Main St     Hotels  Las Vegas  36.171617 -115.146375
# 3  1 Main St     Hotels  Las Vegas  36.171617 -115.146375
# 4  1 Main St     Hotels  Las Vegas  36.171617 -115.146375
#
#                                  name  postalCode province  \
# 0  Plaza Hotel and Casino - Las Vegas       89101       NV
# 1  Plaza Hotel and Casino - Las Vegas       89101       NV
# 2  Plaza Hotel and Casino - Las Vegas       89101       NV
# 3  Plaza Hotel and Casino - Las Vegas       89101       NV
# 4  Plaza Hotel and Casino - Las Vegas       89101       NV
#
#            reviews.date  reviews.rating  \
# 0  2016-07-17T00:00:00Z             4.0
# 1  2016-07-15T00:00:00Z             4.0
# 2  2016-07-13T00:00:00Z             3.0
# 3  2016-07-24T00:00:00Z             4.0
# 4  2016-07-15T00:00:00Z             4.0
#
# ...

# %%
len(reviewsfile1)
# Out:
# 291

# %%
csv_path2 = 'Datafiniti_Hotel_Review_cleaned.csv'
reviewsfile2=pd.read_csv(csv_path2)
reviewsfile2.head()
# Out:
#                  address    categories       city   latitude  longitude  \
# 0  200 North Main Street  Hotels,Hotel  Las Vegas  36.174320 -115.14565
# 1     200 Fremont Street  Hotels,Hotel  Las Vegas  36.170891 -115.14307
# 2     200 Fremont Street  Hotels,Hotel  Las Vegas  36.170891 -115.14307
# 3     200 Fremont Street  Hotels,Hotel  Las Vegas  36.170891 -115.14307
# 4     200 Fremont Street  Hotels,Hotel  Las Vegas  36.170891 -115.14307
#
#                                        name postalCode province  \
# 0  Main Street Station Casino Brewery Hotel      89101       NV
# 1                    Fremont Hotel & Casino      89101       NV
# 2                    Fremont Hotel & Casino      89101       NV
# 3                    Fremont Hotel & Casino      89101       NV
# 4                    Fremont Hotel & Casino      89101       NV
#
#                reviews.date  reviews.rating  \
# 0  2016-11-23T00:00:00.000Z            4.40
# 1  2017-03-15T00:00:00.000Z            2.10
# ...

# %%
len(reviewsfile2)
# Out:
# 506

# %%
#merge files into 1
combined_file_1 = pd.merge(reviewsfile1, reviewsfile2, on='address', how='outer')
combined_file_1.head(500)
# Out:
#                     address categories_x     city_x  latitude_x  longitude_x  \
# 0                 1 Main St       Hotels  Las Vegas   36.171617  -115.146375
# 1                 1 Main St       Hotels  Las Vegas   36.171617  -115.146375
# 2                 1 Main St       Hotels  Las Vegas   36.171617  -115.146375
# 3                 1 Main St       Hotels  Las Vegas   36.171617  -115.146375
# 4                 1 Main St       Hotels  Las Vegas   36.171617  -115.146375
# ..                      ...          ...        ...         ...          ...
# 495  160 East Flamingo Road          NaN        NaN         NaN          NaN
# 496  160 East Flamingo Road          NaN        NaN         NaN          NaN
# 497  160 East Flamingo Road          NaN        NaN         NaN          NaN
# 498  160 East Flamingo Road          NaN        NaN         NaN          NaN
# 499  160 East Flamingo Road          NaN        NaN         NaN          NaN
#
# ...
